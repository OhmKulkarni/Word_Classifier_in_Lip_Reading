# %%
import cv2
import numpy as np
import os
import dlib
from imutils import face_utils

# Initialize dlib's face detector (HOG-based) and the facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# Augmentation functions
def augment_brightness(frame, factor=1.5):
    """Adjust brightness by multiplying pixel values."""
    return np.clip(frame * factor, 0, 255).astype(np.uint8)

def augment_contrast(frame, factor=1.5):
    """Adjust contrast by scaling pixel values around the mean."""
    mean_intensity = np.mean(frame)
    return np.clip((1 - factor) * mean_intensity + factor * frame, 0, 255).astype(np.uint8)

def augment_rotation(frame, angle=15):
    """Rotate the image by a given angle in degrees."""
    (h, w) = frame.shape[:2]
    center = (w // 2, h // 2)
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(frame, matrix, (w, h), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_REFLECT)

def augment_flip(frame):
    """Flip the frame horizontally."""
    return cv2.flip(frame, 1)

def augment_gaussian_noise(frame, mean=0, stddev=10):
    """Add Gaussian noise to the frame."""
    noise = np.random.normal(mean, stddev, frame.shape).astype(np.uint8)
    return np.clip(frame + noise, 0, 255).astype(np.uint8)

# Function to preprocess individual frames
def preprocess_frame(frame, apply_augmentations=None):
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray_frame)
    if len(faces) > 0:
        face = faces[0]
        landmarks = predictor(gray_frame, face)
        landmarks = face_utils.shape_to_np(landmarks)
        (x, y, w, h) = cv2.boundingRect(landmarks[48:68])
        roi = gray_frame[y:y+h, x:x+w]  # Extract lip region

        # Apply augmentations on the lip region (ROI) if specified
        if apply_augmentations:
            for aug in apply_augmentations:
                roi = aug(roi)

        # Resize the lip region to 64x64 for consistency in model input size
        resized_frame = cv2.resize(roi, (64, 64))
    else:
        # If no face is detected, resize the entire frame to 64x64 and augment if required
        resized_frame = cv2.resize(gray_frame, (64, 64))
        if apply_augmentations:
            for aug in apply_augmentations:
                resized_frame = aug(resized_frame)

    # Normalize and add a channel dimension
    normalized_frame = resized_frame[..., np.newaxis] / 255.0
    return normalized_frame

# Function to adjust video length to exactly 60 frames
def adjust_video_length(frames, target_length=60):
    length = len(frames)
    if length > target_length:
        return frames[:target_length]
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad
    return np.pad(frames, ((left_pad, right_pad), (0, 0), (0, 0), (0, 0)), mode='reflect')[:target_length]

# Function to apply augmentations to the video
def apply_augmentations(frames, video_name, output_folder, processed_files, total_files):
    augmentation_combinations = {
        '': [],  # Original
        '_aug_brightness': [augment_brightness],
        '_aug_contrast': [augment_contrast],
        '_aug_rotation': [augment_rotation],
        '_aug_flip': [augment_flip],
        '_aug_gaussian': [augment_gaussian_noise],
        '_aug_brightness_contrast': [augment_brightness, augment_contrast],
        '_aug_brightness_rotation': [augment_brightness, augment_rotation],
        '_aug_brightness_flip': [augment_brightness, augment_flip],
        '_aug_brightness_gaussian': [augment_brightness, augment_gaussian_noise],
        '_aug_contrast_rotation': [augment_contrast, augment_rotation],
        '_aug_contrast_flip': [augment_contrast, augment_flip],
        '_aug_contrast_gaussian': [augment_contrast, augment_gaussian_noise],
        '_aug_rotation_flip': [augment_rotation, augment_flip],
        '_aug_rotation_gaussian': [augment_rotation, augment_gaussian_noise],
        '_aug_flip_gaussian': [augment_flip, augment_gaussian_noise],
        '_aug_brightness_contrast_rotation_flip_gaussian': [
            augment_brightness, augment_contrast, augment_rotation, augment_flip, augment_gaussian_noise
        ],
    }

    for suffix, aug_list in augmentation_combinations.items():
        augmented_frames = [preprocess_frame(frame, apply_augmentations=aug_list) for frame in frames]
        adjusted_frames = adjust_video_length(augmented_frames)
        
        # Remove repetition in output file name
        output_filename = f"{video_name}{suffix}.npy"
        output_path = os.path.join(output_folder, output_filename)
        
        np.save(output_path, np.array(adjusted_frames, dtype=np.float16))
        processed_files += 1
        print(f"Saved: {output_path} ({processed_files}/{total_files} total files saved)")

    return processed_files

# Function to preprocess all videos in a folder
def preprocess_videos(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    total_videos = sum([len(files) for _, _, files in os.walk(input_folder)])
    total_files = total_videos * 17  # 17 different versions per video (original + 16 augmentations)
    processed_files = 0

    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                cap = cv2.VideoCapture(video_path)
                frames = []
                
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break
                    frames.append(frame)
                
                cap.release()

                # Use only the `video_file` name, removing any repetitive parts in the final output filename
                video_name = os.path.splitext(video_file)[0]  # Removes the file extension (.avi)

                try:
                    processed_files = apply_augmentations(frames, video_name, output_folder, processed_files, total_files)
                except Exception as e:
                    print(f"Error processing {video_name}: {e}")

# Paths to your data folders
input_folder = 'data'
output_folder = 'preprocessed_data'

# Preprocess the videos and apply augmentations
preprocess_videos(input_folder, output_folder)
# Out:
# Saved: preprocessed_data\Speaker1_Session1_apple_1.npy (1/85000 total files saved)
# Saved: preprocessed_data\Speaker1_Session1_apple_1_aug_brightness.npy (2/85000 total files saved)
# Saved: preprocessed_data\Speaker1_Session1_apple_1_aug_contrast.npy (3/85000 total files saved)
# Saved: preprocessed_data\Speaker1_Session1_apple_1_aug_rotation.npy (4/85000 total files saved)
# Saved: preprocessed_data\Speaker1_Session1_apple_1_aug_flip.npy (5/85000 total files saved)
# KeyboardInterrupt

# %%
# Import necessary libraries
import cv2
import numpy as np
import os
import dlib
from imutils import face_utils

# Initialize dlib's face detector (HOG-based) and the facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# Initialize a dictionary to keep track of the frame counts for each video
frame_counts_per_video = {}

# Function to preprocess individual frames
def preprocess_frame(frame):
    # Convert the frame to grayscale (since color isn't needed for lip reading)
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = detector(gray_frame)

    # Check if any face is detected
    if len(faces) > 0:
        # Take the first detected face (assume it's the most relevant one)
        face = faces[0]

        # Get facial landmarks (68 points) using the predictor
        landmarks = predictor(gray_frame, face)
        landmarks = face_utils.shape_to_np(landmarks)

        # Extract the bounding box of the lip region (landmarks 48 to 67)
        (x, y, w, h) = cv2.boundingRect(landmarks[48:68])
        roi = gray_frame[y:y+h, x:x+w]  # Region of Interest (lips area)

        # Resize the lip region to 64x64 (for consistency in model input size)
        resized_frame = cv2.resize(roi, (64, 64))
    else:
        # If no face is detected, resize the entire frame to 64x64
        resized_frame = cv2.resize(gray_frame, (64, 64))

    # Add a channel dimension and normalize pixel values to [0, 1]
    normalized_frame = resized_frame[..., np.newaxis] / 255.0

    # Return the processed frame
    return normalized_frame

# Function to adjust video length to exactly 60 frames using truncation or mirror padding
def adjust_video_length(frames, target_length=60):
    length = len(frames)

    if length > target_length:
        return frames[:target_length]  # Truncate if longer than target length

    # Calculate padding needed
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad

    # Create mirror padded video
    padded_video = np.pad(frames, ((left_pad, right_pad), (0, 0), (0, 0), (0, 0)), mode='reflect')

    return padded_video[:target_length]  # Ensure exactly target_length frames

# Function to preprocess all videos in a folder
def preprocess_videos(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each session folder
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                cap = cv2.VideoCapture(video_path)

                frames = []  # List to store all the frames in the current video

                # Loop through each frame of the video
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break
                    # Preprocess each frame using the defined preprocess_frame function
                    processed_frame = preprocess_frame(frame)
                    frames.append(processed_frame)

                cap.release()  # Release the video capture

                # Adjust video length to exactly 60 frames using truncation or mirror padding
                adjusted_frames = adjust_video_length(frames)

                # Convert adjusted_frames list to a NumPy array before saving
                adjusted_frames_array = np.array(adjusted_frames)

                # Create proper output file name based on the session and video
                output_file_name = f"{session_folder}_{video_file}".replace('.avi', '')  # Remove any extensions
                output_video_path = os.path.join(output_folder, f"{output_file_name}.npy")

                # Replace or create new file with the proper naming convention
                if os.path.exists(output_video_path):
                    print(f"Replacing existing file: {output_video_path}")
                else:
                    print(f"Saving new preprocessed video: {output_video_path}")

                # Save the preprocessed video as a .npy file with float16 data type
                np.save(output_video_path, adjusted_frames_array.astype(np.float16))

                # Store frame counts for summary
                frame_counts_per_video[output_file_name] = {
                    'total': len(frames),
                    'processed': len(adjusted_frames_array)
                }

    print("\nSummary of frame counts for each video:")
    for video_file, counts in frame_counts_per_video.items():
        print(f"{video_file}: Total Frames = {counts['total']}, Processed Frames = {counts['processed']}")

# Paths to your data folders - adjust these paths as necessary!
input_folder = 'test_data'           # Path where your input videos are stored.
output_folder = 'preprocessed_test_data'  # Path where you want to save preprocessed videos.

# Preprocess the videos and adjust them to exactly 60 frames each
preprocess_videos(input_folder, output_folder)
# Out:
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_1.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_10.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_11.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_12.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_13.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_14.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_15.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_16.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_17.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_18.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_19.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_2.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_20.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_21.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_22.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_23.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_24.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_25.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_26.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_27.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_28.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_29.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_3.npy
# Saving new preprocessed video: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_30.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_4.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_5.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_6.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_7.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_8.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_9.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_1.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_10.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_11.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_12.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_13.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_14.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_15.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_16.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_17.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_18.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_19.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_2.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_20.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_21.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_22.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_23.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_24.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_25.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_26.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_27.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_28.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_29.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_3.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_30.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_4.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_5.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_6.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_7.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_8.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_9.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_1.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_10.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_11.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_12.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_13.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_14.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_15.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_16.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_17.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_18.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_19.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_2.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_20.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_21.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_22.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_23.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_24.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_25.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_26.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_27.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_28.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_29.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_3.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_30.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_4.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_5.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_6.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_7.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_8.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_9.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_1.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_10.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_11.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_12.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_13.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_14.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_15.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_16.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_17.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_18.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_19.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_2.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_20.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_21.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_22.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_23.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_24.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_25.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_26.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_27.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_28.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_29.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_3.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_30.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_4.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_5.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_6.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_7.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_8.npy
# Replacing existing file: preprocessed_test_data\TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_9.npy
#
# Summary of frame counts for each video:
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_1: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_10: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_11: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_12: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_13: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_14: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_15: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_16: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_17: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_18: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_19: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_2: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_20: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_21: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_22: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_23: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_24: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_25: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_26: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_27: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_28: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_29: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_3: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_30: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_4: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_5: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_6: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_7: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_8: Total Frames = 59, Processed Frames = 60
# TestSpeaker1_Session1_cat_TestSpeaker1_Session1_cat_9: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_1: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_10: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_11: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_12: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_13: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_14: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_15: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_16: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_17: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_18: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_19: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_2: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_20: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_21: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_22: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_23: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_24: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_25: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_26: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_27: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_28: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_29: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_3: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_30: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_4: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_5: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_6: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_7: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_8: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_chair_TestSpeaker1_Session1_chair_9: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_1: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_10: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_11: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_12: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_13: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_14: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_15: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_16: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_17: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_18: Total Frames = 54, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_19: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_2: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_20: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_21: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_22: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_23: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_24: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_25: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_26: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_27: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_28: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_29: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_3: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_30: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_4: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_5: Total Frames = 65, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_6: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_7: Total Frames = 64, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_8: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_clock_TestSpeaker1_Session1_clock_9: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_1: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_10: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_11: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_12: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_13: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_14: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_15: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_16: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_17: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_18: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_19: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_2: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_20: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_21: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_22: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_23: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_24: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_25: Total Frames = 63, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_26: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_27: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_28: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_29: Total Frames = 60, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_3: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_30: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_4: Total Frames = 61, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_5: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_6: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_7: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_8: Total Frames = 62, Processed Frames = 60
# TestSpeaker1_Session1_coat_TestSpeaker1_Session1_coat_9: Total Frames = 61, Processed Frames = 60

# %%
import cv2
import numpy as np
import os
import dlib
import cupy as cp
import tensorflow as tf

# Enable GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Initialize face detector and predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# GPU-accelerated augmentation functions
def augment_brightness(frame_gpu, factor=1.1):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_strong(frame_gpu, factor=1.3):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_negative(frame_gpu, factor=0.7):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_contrast(frame_gpu, factor=1.1):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_strong(frame_gpu, factor=1.3):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_negative(frame_gpu, factor=0.7):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_rotation(frame_gpu, angle=10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_strong(frame_gpu, angle=20):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_negative(frame_gpu, angle=-10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_flip(frame_gpu):
    return cp.fliplr(frame_gpu)

def augment_gaussian_noise(frame_gpu, mean=0, stddev=0.005):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_strong(frame_gpu, mean=0, stddev=0.01):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_negative(frame_gpu, mean=0, stddev=0.003):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def preprocess_frame(frame):
    # Convert to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect face
    faces = detector(gray_frame)
    
    if len(faces) > 0:
        face = faces[0]
        landmarks = predictor(gray_frame, face)
        landmarks = np.array([[p.x, p.y] for p in landmarks.parts()])[48:68]  # Lip region
        x, y, w, h = cv2.boundingRect(landmarks)
        roi = gray_frame[y:y+h, x:x+w]
    else:
        roi = gray_frame
    
    # Resize to 128x128
    resized_frame = cv2.resize(roi, (128, 128))
    
    # Move to GPU and normalize
    frame_gpu = cp.asarray(resized_frame, dtype=cp.float32)
    frame_gpu = frame_gpu / 255.0  # Normalize to 0-1 range
    
    return frame_gpu

def adjust_video_length(frames_list, target_length=60):
    # Convert list of CuPy arrays to a single stacked array
    frames = cp.stack(frames_list)
    length = len(frames)
    
    if length > target_length:
        return cp.asnumpy(frames[:target_length])
    
    # Move to CPU for padding operation
    frames_cpu = cp.asnumpy(frames)
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad
    
    padded = np.pad(frames_cpu, ((left_pad, right_pad), (0, 0), (0, 0)), mode='reflect')
    return padded[:target_length]

def process_video(video_path, output_folder, video_name):
    print(f"Processing {video_name}")
    
    # Read video frames
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    cap.release()
    
    # Define augmentation combinations
    augmentation_combinations = [
        ('no_aug', []),
        ('brightness', [augment_brightness]),
        ('brightness_strong', [augment_brightness_strong]),
        ('brightness_negative', [augment_brightness_negative]),
        ('contrast', [augment_contrast]),
        ('contrast_strong', [augment_contrast_strong]), 
        ('contrast_negative', [augment_contrast_negative]),
        ('rotation', [augment_rotation]),
        ('rotation_strong', [augment_rotation_strong]),
        ('rotation_negative', [augment_rotation_negative]),
        ('flip', [augment_flip]),
        ('gaussian', [augment_gaussian_noise]),
        ('gaussian_strong', [augment_gaussian_noise_strong]),
        ('gaussian_negative', [augment_gaussian_noise_negative])
    ]
    
    # Process frames
    processed_frames = [preprocess_frame(frame) for frame in frames]
    
    for aug_level, aug_list in augmentation_combinations:
        augmented_frames = []
        
        for frame_gpu in processed_frames:
            current_frame = cp.copy(frame_gpu)
            
            # Apply augmentations
            for aug_func in aug_list:
                current_frame = aug_func(current_frame)
            
            augmented_frames.append(current_frame)
        
        # Adjust to 60 frames and save
        adjusted_frames = adjust_video_length(augmented_frames)
        output_path = os.path.join(output_folder, f"{video_name}_{aug_level}.npy")
        np.save(output_path, adjusted_frames.astype(np.float16))
        print(f"Saved: {output_path}")
        
        # Free GPU memory
        cp.get_default_memory_pool().free_all_blocks()

def preprocess_videos(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_videos = sum([len(files) for _, _, files in os.walk(input_folder)])
    processed = 0
    
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                video_name = os.path.splitext(video_file)[0]
                
                try:
                    process_video(video_path, output_folder, video_name)
                    processed += 1
                    print(f"Progress: {processed}/{total_videos} videos processed")
                except Exception as e:
                    print(f"Error processing {video_name}: {e}")
                    
                # Free GPU memory after each video
                cp.get_default_memory_pool().free_all_blocks()

if __name__ == "__main__":
    input_folder = 'test_data'
    output_folder = 'preprocessed_test_data'
    
    # Clear any existing GPU memory
    cp.get_default_memory_pool().free_all_blocks()
    
    preprocess_videos(input_folder, output_folder)
# Out:
# Processing TestSpeaker1_Session1_apple_1
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_gaussian_negative.npy
# Progress: 1/750 videos processed
# Processing TestSpeaker1_Session1_apple_10
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_gaussian_negative.npy
# Progress: 2/750 videos processed
# Processing TestSpeaker1_Session1_apple_11
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_gaussian_negative.npy
# Progress: 3/750 videos processed
# Processing TestSpeaker1_Session1_apple_12
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_gaussian_negative.npy
# Progress: 4/750 videos processed
# Processing TestSpeaker1_Session1_apple_13
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_gaussian_negative.npy
# Progress: 5/750 videos processed
# Processing TestSpeaker1_Session1_apple_14
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_gaussian_negative.npy
# Progress: 6/750 videos processed
# Processing TestSpeaker1_Session1_apple_15
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_gaussian_negative.npy
# Progress: 7/750 videos processed
# Processing TestSpeaker1_Session1_apple_16
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_gaussian_negative.npy
# Progress: 8/750 videos processed
# Processing TestSpeaker1_Session1_apple_17
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_gaussian_negative.npy
# Progress: 9/750 videos processed
# Processing TestSpeaker1_Session1_apple_18
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_gaussian_negative.npy
# Progress: 10/750 videos processed
# Processing TestSpeaker1_Session1_apple_19
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_gaussian_negative.npy
# Progress: 11/750 videos processed
# Processing TestSpeaker1_Session1_apple_2
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_gaussian_negative.npy
# Progress: 12/750 videos processed
# Processing TestSpeaker1_Session1_apple_20
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_gaussian_negative.npy
# Progress: 13/750 videos processed
# Processing TestSpeaker1_Session1_apple_21
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_gaussian_negative.npy
# Progress: 14/750 videos processed
# Processing TestSpeaker1_Session1_apple_22
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_gaussian_negative.npy
# Progress: 15/750 videos processed
# Processing TestSpeaker1_Session1_apple_23
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_gaussian_negative.npy
# Progress: 16/750 videos processed
# Processing TestSpeaker1_Session1_apple_24
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_gaussian_negative.npy
# Progress: 17/750 videos processed
# Processing TestSpeaker1_Session1_apple_25
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_25_gaussian_negative.npy
# Progress: 18/750 videos processed
# Processing TestSpeaker1_Session1_apple_26
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_26_gaussian_negative.npy
# Progress: 19/750 videos processed
# Processing TestSpeaker1_Session1_apple_27
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_27_gaussian_negative.npy
# Progress: 20/750 videos processed
# Processing TestSpeaker1_Session1_apple_28
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_28_gaussian_negative.npy
# Progress: 21/750 videos processed
# Processing TestSpeaker1_Session1_apple_29
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_29_gaussian_negative.npy
# Progress: 22/750 videos processed
# Processing TestSpeaker1_Session1_apple_3
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_3_gaussian_negative.npy
# Progress: 23/750 videos processed
# Processing TestSpeaker1_Session1_apple_30
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_30_gaussian_negative.npy
# Progress: 24/750 videos processed
# Processing TestSpeaker1_Session1_apple_4
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_4_gaussian_negative.npy
# Progress: 25/750 videos processed
# Processing TestSpeaker1_Session1_apple_5
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_5_gaussian_negative.npy
# Progress: 26/750 videos processed
# Processing TestSpeaker1_Session1_apple_6
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_6_gaussian_negative.npy
# Progress: 27/750 videos processed
# Processing TestSpeaker1_Session1_apple_7
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_7_gaussian_negative.npy
# Progress: 28/750 videos processed
# Processing TestSpeaker1_Session1_apple_8
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_8_gaussian_negative.npy
# Progress: 29/750 videos processed
# Processing TestSpeaker1_Session1_apple_9
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_9_gaussian_negative.npy
# Progress: 30/750 videos processed
# Processing TestSpeaker1_Session1_baby_1
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_1_gaussian_negative.npy
# Progress: 31/750 videos processed
# Processing TestSpeaker1_Session1_baby_10
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_10_gaussian_negative.npy
# Progress: 32/750 videos processed
# Processing TestSpeaker1_Session1_baby_11
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_11_gaussian_negative.npy
# Progress: 33/750 videos processed
# Processing TestSpeaker1_Session1_baby_12
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_12_gaussian_negative.npy
# Progress: 34/750 videos processed
# Processing TestSpeaker1_Session1_baby_13
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_13_gaussian_negative.npy
# Progress: 35/750 videos processed
# Processing TestSpeaker1_Session1_baby_14
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_14_gaussian_negative.npy
# Progress: 36/750 videos processed
# Processing TestSpeaker1_Session1_baby_15
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_15_gaussian_negative.npy
# Progress: 37/750 videos processed
# Processing TestSpeaker1_Session1_baby_16
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_16_gaussian_negative.npy
# Progress: 38/750 videos processed
# Processing TestSpeaker1_Session1_baby_17
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_17_gaussian_negative.npy
# Progress: 39/750 videos processed
# Processing TestSpeaker1_Session1_baby_18
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_18_gaussian_negative.npy
# Progress: 40/750 videos processed
# Processing TestSpeaker1_Session1_baby_19
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_baby_19_gaussian_negative.npy
# Progress: 41/750 videos processed
# Processing TestSpeaker1_Session1_baby_2
# ...
# Progress: 736/750 videos processed
# Processing TestSpeaker1_Session1_yes_24
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_24_gaussian_negative.npy
# Progress: 737/750 videos processed
# Processing TestSpeaker1_Session1_yes_25
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_25_gaussian_negative.npy
# Progress: 738/750 videos processed
# Processing TestSpeaker1_Session1_yes_26
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_26_gaussian_negative.npy
# Progress: 739/750 videos processed
# Processing TestSpeaker1_Session1_yes_27
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_27_gaussian_negative.npy
# Progress: 740/750 videos processed
# Processing TestSpeaker1_Session1_yes_28
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_28_gaussian_negative.npy
# Progress: 741/750 videos processed
# Processing TestSpeaker1_Session1_yes_29
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_29_gaussian_negative.npy
# Progress: 742/750 videos processed
# Processing TestSpeaker1_Session1_yes_3
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_3_gaussian_negative.npy
# Progress: 743/750 videos processed
# Processing TestSpeaker1_Session1_yes_30
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_30_gaussian_negative.npy
# Progress: 744/750 videos processed
# Processing TestSpeaker1_Session1_yes_4
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_4_gaussian_negative.npy
# Progress: 745/750 videos processed
# Processing TestSpeaker1_Session1_yes_5
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_5_gaussian_negative.npy
# Progress: 746/750 videos processed
# Processing TestSpeaker1_Session1_yes_6
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_6_gaussian_negative.npy
# Progress: 747/750 videos processed
# Processing TestSpeaker1_Session1_yes_7
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_7_gaussian_negative.npy
# Progress: 748/750 videos processed
# Processing TestSpeaker1_Session1_yes_8
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_8_gaussian_negative.npy
# Progress: 749/750 videos processed
# Processing TestSpeaker1_Session1_yes_9
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_brightness.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_brightness_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_contrast_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_contrast_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_rotation.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_rotation_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_rotation_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_flip.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_gaussian.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_gaussian_strong.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_yes_9_gaussian_negative.npy
# Progress: 750/750 videos processed

# %%
import cv2
import numpy as np
import os
import dlib
import cupy as cp
import tensorflow as tf

# Enable GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Initialize face detector and predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# GPU-accelerated augmentation functions
def augment_brightness(frame_gpu, factor=1.5):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_contrast(frame_gpu, factor=1.5):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_rotation(frame_gpu, angle=15):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_flip(frame_gpu):
    return cp.fliplr(frame_gpu)

def augment_gaussian_noise(frame_gpu, mean=0, stddev=0.01):  # Significantly reduced noise
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def preprocess_frame(frame):
    # Convert to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect face
    faces = detector(gray_frame)
    
    if len(faces) > 0:
        face = faces[0]
        landmarks = predictor(gray_frame, face)
        landmarks = np.array([[p.x, p.y] for p in landmarks.parts()])[48:68]  # Lip region
        x, y, w, h = cv2.boundingRect(landmarks)
        roi = gray_frame[y:y+h, x:x+w]
    else:
        roi = gray_frame
    
    # Resize to 64x64
    resized_frame = cv2.resize(roi, (64, 64))
    
    # Move to GPU and normalize
    frame_gpu = cp.asarray(resized_frame, dtype=cp.float32)
    frame_gpu = frame_gpu / 255.0  # Normalize to 0-1 range
    
    return frame_gpu

def adjust_video_length(frames_list, target_length=60):
    # Convert list of CuPy arrays to a single stacked array
    frames = cp.stack(frames_list)
    length = len(frames)
    
    if length > target_length:
        return cp.asnumpy(frames[:target_length])
    
    # Move to CPU for padding operation
    frames_cpu = cp.asnumpy(frames)
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad
    
    padded = np.pad(frames_cpu, ((left_pad, right_pad), (0, 0), (0, 0)), mode='reflect')
    return padded[:target_length]

def process_video(video_path, output_folder, video_name):
    print(f"Processing {video_name}")
    
    # Read video frames
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    cap.release()
    
    # Define augmentation combinations
    augmentation_combinations = {
        '': [],
        '_aug_brightness': [augment_brightness],
        '_aug_contrast': [augment_contrast],
        '_aug_rotation': [augment_rotation],
        '_aug_flip': [augment_flip],
        '_aug_gaussian': [augment_gaussian_noise],
        '_aug_brightness_contrast': [augment_brightness, augment_contrast],
        '_aug_brightness_rotation': [augment_brightness, augment_rotation],
        '_aug_brightness_flip': [augment_brightness, augment_flip],
        '_aug_brightness_gaussian': [augment_brightness, augment_gaussian_noise],
        '_aug_contrast_rotation': [augment_contrast, augment_rotation],
        '_aug_contrast_flip': [augment_contrast, augment_flip],
        '_aug_contrast_gaussian': [augment_contrast, augment_gaussian_noise],
        '_aug_rotation_flip': [augment_rotation, augment_flip],
        '_aug_rotation_gaussian': [augment_rotation, augment_gaussian_noise],
        '_aug_flip_gaussian': [augment_flip, augment_gaussian_noise],
        '_aug_brightness_contrast_rotation_flip_gaussian': [
            augment_brightness, augment_contrast, augment_rotation, augment_flip, augment_gaussian_noise
        ]
    }
    
    # Process frames
    processed_frames = [preprocess_frame(frame) for frame in frames]
    
    for suffix, aug_list in augmentation_combinations.items():
        augmented_frames = []
        
        for frame_gpu in processed_frames:
            current_frame = cp.copy(frame_gpu)
            
            # Apply augmentations
            for aug_func in aug_list:
                current_frame = aug_func(current_frame)
            
            augmented_frames.append(current_frame)
        
        # Adjust to 60 frames and save
        adjusted_frames = adjust_video_length(augmented_frames)
        output_path = os.path.join(output_folder, f"{video_name}{suffix}.npy")
        np.save(output_path, adjusted_frames.astype(np.float16))
        print(f"Saved: {output_path}")
        
        # Free GPU memory
        cp.get_default_memory_pool().free_all_blocks()

def preprocess_videos(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_videos = sum([len(files) for _, _, files in os.walk(input_folder)])
    processed = 0
    
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                video_name = os.path.splitext(video_file)[0]
                
                try:
                    process_video(video_path, output_folder, video_name)
                    processed += 1
                    print(f"Progress: {processed}/{total_videos} videos processed")
                except Exception as e:
                    print(f"Error processing {video_name}: {e}")
                    
                # Free GPU memory after each video
                cp.get_default_memory_pool().free_all_blocks()

if __name__ == "__main__":
    input_folder = 'data'
    output_folder = 'preprocessed_data'
    
    # Clear any existing GPU memory
    cp.get_default_memory_pool().free_all_blocks()
    
    preprocess_videos(input_folder, output_folder)
