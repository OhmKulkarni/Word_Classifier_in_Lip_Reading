# %%
# Import necessary libraries
import cv2
import numpy as np
import os
import dlib
from imutils import face_utils

# Initialize dlib's face detector (HOG-based) and the facial landmark predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# Initialize a dictionary to keep track of the frame counts for each video
frame_counts_per_video = {}

# Function to preprocess individual frames
def preprocess_frame(frame):
    # Convert the frame to grayscale (since color isn't needed for lip reading)
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = detector(gray_frame)

    # Check if any face is detected
    if len(faces) > 0:
        # Take the first detected face (assume it's the most relevant one)
        face = faces[0]

        # Get facial landmarks (68 points) using the predictor
        landmarks = predictor(gray_frame, face)
        landmarks = face_utils.shape_to_np(landmarks)

        # Extract the bounding box of the lip region (landmarks 48 to 67)
        (x, y, w, h) = cv2.boundingRect(landmarks[48:68])
        roi = gray_frame[y:y+h, x:x+w]  # Region of Interest (lips area)

        # Resize the lip region to 64x64 (for consistency in model input size)
        resized_frame = cv2.resize(roi, (64, 64))
    else:
        # If no face is detected, resize the entire frame to 64x64
        resized_frame = cv2.resize(gray_frame, (64, 64))

    # Add a channel dimension and normalize pixel values to [0, 1]
    normalized_frame = resized_frame[..., np.newaxis] / 255.0

    # Return the processed frame
    return normalized_frame

# Function to adjust video length to exactly 60 frames using truncation or mirror padding
def adjust_video_length(frames, target_length=60):
    length = len(frames)

    if length > target_length:
        return frames[:target_length]  # Truncate if longer than target length

    # Calculate padding needed
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad

    # Create mirror padded video
    padded_video = np.pad(frames, ((left_pad, right_pad), (0, 0), (0, 0), (0, 0)), mode='reflect')

    return padded_video[:target_length]  # Ensure exactly target_length frames

# Function to preprocess all videos in a folder
def preprocess_videos(input_folder, output_folder):
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Loop through each session folder
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                cap = cv2.VideoCapture(video_path)

                frames = []  # List to store all the frames in the current video

                # Loop through each frame of the video
                while True:
                    ret, frame = cap.read()
                    if not ret:
                        break
                    # Preprocess each frame using the defined preprocess_frame function
                    processed_frame = preprocess_frame(frame)
                    frames.append(processed_frame)

                cap.release()  # Release the video capture

                # Adjust video length to exactly 60 frames using truncation or mirror padding
                adjusted_frames = adjust_video_length(frames)

                # Convert adjusted_frames list to a NumPy array before saving
                adjusted_frames_array = np.array(adjusted_frames)

                # Create proper output file name based on the session and video
                output_file_name = f"{session_folder}_{video_file}".replace('.avi', '')  # Remove any extensions
                output_video_path = os.path.join(output_folder, f"{output_file_name}.npy")

                # Replace or create new file with the proper naming convention
                if os.path.exists(output_video_path):
                    print(f"Replacing existing file: {output_video_path}")
                else:
                    print(f"Saving new preprocessed video: {output_video_path}")

                # Save the preprocessed video as a .npy file with float16 data type
                np.save(output_video_path, adjusted_frames_array.astype(np.float16))

                # Store frame counts for summary
                frame_counts_per_video[output_file_name] = {
                    'total': len(frames),
                    'processed': len(adjusted_frames_array)
                }

    print("\nSummary of frame counts for each video:")
    for video_file, counts in frame_counts_per_video.items():
        print(f"{video_file}: Total Frames = {counts['total']}, Processed Frames = {counts['processed']}")

# Paths to your data folders - adjust these paths as necessary!
input_folder = 'test_data'           # Path where your input videos are stored.
output_folder = 'preprocessed_test_data'  # Path where you want to save preprocessed videos.

# Preprocess the videos and adjust them to exactly 60 frames each
preprocess_videos(input_folder, output_folder)

# %%
import cv2
import numpy as np
import os
import dlib
import cupy as cp
import tensorflow as tf

# Enable GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Initialize face detector and predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# GPU-accelerated augmentation functions
def augment_brightness(frame_gpu, factor=1.1):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_strong(frame_gpu, factor=1.3):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_negative(frame_gpu, factor=0.7):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_contrast(frame_gpu, factor=1.1):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_strong(frame_gpu, factor=1.3):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_negative(frame_gpu, factor=0.7):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_rotation(frame_gpu, angle=10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_strong(frame_gpu, angle=20):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_negative(frame_gpu, angle=-10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_flip(frame_gpu):
    return cp.fliplr(frame_gpu)

def augment_gaussian_noise(frame_gpu, mean=0, stddev=0.005):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_strong(frame_gpu, mean=0, stddev=0.01):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_negative(frame_gpu, mean=0, stddev=0.003):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def preprocess_frame(frame):
    # Convert to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect face
    faces = detector(gray_frame)
    
    if len(faces) > 0:
        face = faces[0]
        landmarks = predictor(gray_frame, face)
        landmarks = np.array([[p.x, p.y] for p in landmarks.parts()])[48:68]  # Lip region
        x, y, w, h = cv2.boundingRect(landmarks)
        roi = gray_frame[y:y+h, x:x+w]
    else:
        roi = gray_frame
    
    # Resize to 128x128
    resized_frame = cv2.resize(roi, (256, 256))
    
    # Move to GPU and normalize
    frame_gpu = cp.asarray(resized_frame, dtype=cp.float32)
    frame_gpu = frame_gpu / 255.0  # Normalize to 0-1 range
    
    return frame_gpu

def adjust_video_length(frames_list, target_length=60):
    # Convert list of CuPy arrays to a single stacked array
    frames = cp.stack(frames_list)
    length = len(frames)
    
    if length > target_length:
        return cp.asnumpy(frames[:target_length])
    
    # Move to CPU for padding operation
    frames_cpu = cp.asnumpy(frames)
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad
    
    padded = np.pad(frames_cpu, ((left_pad, right_pad), (0, 0), (0, 0)), mode='reflect')
    return padded[:target_length]

def process_video(video_path, output_folder, video_name):
    print(f"Processing {video_name}")
    
    # Read video frames
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    cap.release()
    
    # Define augmentation combinations
    augmentation_combinations = [
        ('no_aug', []),
        # ('brightness', [augment_brightness]),
        # ('brightness_strong', [augment_brightness_strong]),
        ('brightness_negative', [augment_brightness_negative]),
        ('contrast', [augment_contrast]),
        # ('contrast_strong', [augment_contrast_strong]), 
        # ('contrast_negative', [augment_contrast_negative]),
        # ('rotation', [augment_rotation]),
        # ('rotation_strong', [augment_rotation_strong]),
        # ('rotation_negative', [augment_rotation_negative]),
        # ('flip', [augment_flip]),
        ('gaussian', [augment_gaussian_noise]),
        # ('gaussian_strong', [augment_gaussian_noise_strong]),
        # ('gaussian_negative', [augment_gaussian_noise_negative])
    ]
    
    # Process frames
    processed_frames = [preprocess_frame(frame) for frame in frames]
    
    for aug_level, aug_list in augmentation_combinations:
        augmented_frames = []
        
        for frame_gpu in processed_frames:
            current_frame = cp.copy(frame_gpu)
            
            # Apply augmentations
            for aug_func in aug_list:
                current_frame = aug_func(current_frame)
            
            augmented_frames.append(current_frame)
        
        # Adjust to 60 frames and save
        adjusted_frames = adjust_video_length(augmented_frames)
        output_path = os.path.join(output_folder, f"{video_name}_{aug_level}.npy")
        np.save(output_path, adjusted_frames.astype(np.float16))
        print(f"Saved: {output_path}")
        
        # Free GPU memory
        cp.get_default_memory_pool().free_all_blocks()

def preprocess_videos(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_videos = sum([len(files) for _, _, files in os.walk(input_folder)])
    processed = 0
    
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                video_name = os.path.splitext(video_file)[0]
                
                try:
                    process_video(video_path, output_folder, video_name)
                    processed += 1
                    print(f"Progress: {processed}/{total_videos} videos processed")
                except Exception as e:
                    print(f"Error processing {video_name}: {e}")
                    
                # Free GPU memory after each video
                cp.get_default_memory_pool().free_all_blocks()

if __name__ == "__main__":
    input_folder = 'data'
    output_folder = 'preprocessed_data'
    
    # Clear any existing GPU memory
    cp.get_default_memory_pool().free_all_blocks()
    
    preprocess_videos(input_folder, output_folder)
# Out:
# Processing Speaker1_Session1_apple_1
# Saved: preprocessed_data\Speaker1_Session1_apple_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_1_gaussian.npy
# Progress: 1/5000 videos processed
# Processing Speaker1_Session1_apple_10
# Saved: preprocessed_data\Speaker1_Session1_apple_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_10_gaussian.npy
# Progress: 2/5000 videos processed
# Processing Speaker1_Session1_apple_2
# Saved: preprocessed_data\Speaker1_Session1_apple_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_2_gaussian.npy
# Progress: 3/5000 videos processed
# Processing Speaker1_Session1_apple_3
# Saved: preprocessed_data\Speaker1_Session1_apple_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_3_gaussian.npy
# Progress: 4/5000 videos processed
# Processing Speaker1_Session1_apple_4
# Saved: preprocessed_data\Speaker1_Session1_apple_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_4_gaussian.npy
# Progress: 5/5000 videos processed
# Processing Speaker1_Session1_apple_5
# Saved: preprocessed_data\Speaker1_Session1_apple_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_5_gaussian.npy
# Progress: 6/5000 videos processed
# Processing Speaker1_Session1_apple_6
# Saved: preprocessed_data\Speaker1_Session1_apple_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_6_gaussian.npy
# Progress: 7/5000 videos processed
# Processing Speaker1_Session1_apple_7
# Saved: preprocessed_data\Speaker1_Session1_apple_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_7_gaussian.npy
# Progress: 8/5000 videos processed
# Processing Speaker1_Session1_apple_8
# Saved: preprocessed_data\Speaker1_Session1_apple_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_8_gaussian.npy
# Progress: 9/5000 videos processed
# Processing Speaker1_Session1_apple_9
# Saved: preprocessed_data\Speaker1_Session1_apple_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_apple_9_gaussian.npy
# Progress: 10/5000 videos processed
# Processing Speaker1_Session1_baby_1
# Saved: preprocessed_data\Speaker1_Session1_baby_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_1_gaussian.npy
# Progress: 11/5000 videos processed
# Processing Speaker1_Session1_baby_10
# Saved: preprocessed_data\Speaker1_Session1_baby_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_10_gaussian.npy
# Progress: 12/5000 videos processed
# Processing Speaker1_Session1_baby_2
# Saved: preprocessed_data\Speaker1_Session1_baby_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_2_gaussian.npy
# Progress: 13/5000 videos processed
# Processing Speaker1_Session1_baby_3
# Saved: preprocessed_data\Speaker1_Session1_baby_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_3_gaussian.npy
# Progress: 14/5000 videos processed
# Processing Speaker1_Session1_baby_4
# Saved: preprocessed_data\Speaker1_Session1_baby_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_4_gaussian.npy
# Progress: 15/5000 videos processed
# Processing Speaker1_Session1_baby_5
# Saved: preprocessed_data\Speaker1_Session1_baby_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_5_gaussian.npy
# Progress: 16/5000 videos processed
# Processing Speaker1_Session1_baby_6
# Saved: preprocessed_data\Speaker1_Session1_baby_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_6_gaussian.npy
# Progress: 17/5000 videos processed
# Processing Speaker1_Session1_baby_7
# Saved: preprocessed_data\Speaker1_Session1_baby_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_7_gaussian.npy
# Progress: 18/5000 videos processed
# Processing Speaker1_Session1_baby_8
# Saved: preprocessed_data\Speaker1_Session1_baby_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_8_gaussian.npy
# Progress: 19/5000 videos processed
# Processing Speaker1_Session1_baby_9
# Saved: preprocessed_data\Speaker1_Session1_baby_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_baby_9_gaussian.npy
# Progress: 20/5000 videos processed
# Processing Speaker1_Session1_ball_1
# Saved: preprocessed_data\Speaker1_Session1_ball_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_1_gaussian.npy
# Progress: 21/5000 videos processed
# Processing Speaker1_Session1_ball_10
# Saved: preprocessed_data\Speaker1_Session1_ball_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_10_gaussian.npy
# Progress: 22/5000 videos processed
# Processing Speaker1_Session1_ball_2
# Saved: preprocessed_data\Speaker1_Session1_ball_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_2_gaussian.npy
# Progress: 23/5000 videos processed
# Processing Speaker1_Session1_ball_3
# Saved: preprocessed_data\Speaker1_Session1_ball_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_3_gaussian.npy
# Progress: 24/5000 videos processed
# Processing Speaker1_Session1_ball_4
# Saved: preprocessed_data\Speaker1_Session1_ball_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_4_gaussian.npy
# Progress: 25/5000 videos processed
# Processing Speaker1_Session1_ball_5
# Saved: preprocessed_data\Speaker1_Session1_ball_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_5_gaussian.npy
# Progress: 26/5000 videos processed
# Processing Speaker1_Session1_ball_6
# Saved: preprocessed_data\Speaker1_Session1_ball_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_6_gaussian.npy
# Progress: 27/5000 videos processed
# Processing Speaker1_Session1_ball_7
# Saved: preprocessed_data\Speaker1_Session1_ball_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_7_gaussian.npy
# Progress: 28/5000 videos processed
# Processing Speaker1_Session1_ball_8
# Saved: preprocessed_data\Speaker1_Session1_ball_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_8_gaussian.npy
# Progress: 29/5000 videos processed
# Processing Speaker1_Session1_ball_9
# Saved: preprocessed_data\Speaker1_Session1_ball_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_ball_9_gaussian.npy
# Progress: 30/5000 videos processed
# Processing Speaker1_Session1_bank_1
# Saved: preprocessed_data\Speaker1_Session1_bank_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_1_gaussian.npy
# Progress: 31/5000 videos processed
# Processing Speaker1_Session1_bank_10
# Saved: preprocessed_data\Speaker1_Session1_bank_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_10_gaussian.npy
# Progress: 32/5000 videos processed
# Processing Speaker1_Session1_bank_2
# Saved: preprocessed_data\Speaker1_Session1_bank_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_2_gaussian.npy
# Progress: 33/5000 videos processed
# Processing Speaker1_Session1_bank_3
# Saved: preprocessed_data\Speaker1_Session1_bank_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_3_gaussian.npy
# Progress: 34/5000 videos processed
# Processing Speaker1_Session1_bank_4
# Saved: preprocessed_data\Speaker1_Session1_bank_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_4_gaussian.npy
# Progress: 35/5000 videos processed
# Processing Speaker1_Session1_bank_5
# Saved: preprocessed_data\Speaker1_Session1_bank_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_5_gaussian.npy
# Progress: 36/5000 videos processed
# Processing Speaker1_Session1_bank_6
# Saved: preprocessed_data\Speaker1_Session1_bank_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_6_gaussian.npy
# Progress: 37/5000 videos processed
# Processing Speaker1_Session1_bank_7
# Saved: preprocessed_data\Speaker1_Session1_bank_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_7_gaussian.npy
# Progress: 38/5000 videos processed
# Processing Speaker1_Session1_bank_8
# Saved: preprocessed_data\Speaker1_Session1_bank_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_8_gaussian.npy
# Progress: 39/5000 videos processed
# Processing Speaker1_Session1_bank_9
# Saved: preprocessed_data\Speaker1_Session1_bank_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bank_9_gaussian.npy
# Progress: 40/5000 videos processed
# Processing Speaker1_Session1_beach_1
# Saved: preprocessed_data\Speaker1_Session1_beach_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_1_gaussian.npy
# Progress: 41/5000 videos processed
# Processing Speaker1_Session1_beach_10
# Saved: preprocessed_data\Speaker1_Session1_beach_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_10_gaussian.npy
# Progress: 42/5000 videos processed
# Processing Speaker1_Session1_beach_2
# Saved: preprocessed_data\Speaker1_Session1_beach_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_2_gaussian.npy
# Progress: 43/5000 videos processed
# Processing Speaker1_Session1_beach_3
# Saved: preprocessed_data\Speaker1_Session1_beach_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_3_gaussian.npy
# Progress: 44/5000 videos processed
# Processing Speaker1_Session1_beach_4
# Saved: preprocessed_data\Speaker1_Session1_beach_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_4_gaussian.npy
# Progress: 45/5000 videos processed
# Processing Speaker1_Session1_beach_5
# Saved: preprocessed_data\Speaker1_Session1_beach_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_5_gaussian.npy
# Progress: 46/5000 videos processed
# Processing Speaker1_Session1_beach_6
# Saved: preprocessed_data\Speaker1_Session1_beach_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_6_gaussian.npy
# Progress: 47/5000 videos processed
# Processing Speaker1_Session1_beach_7
# Saved: preprocessed_data\Speaker1_Session1_beach_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_7_gaussian.npy
# Progress: 48/5000 videos processed
# Processing Speaker1_Session1_beach_8
# Saved: preprocessed_data\Speaker1_Session1_beach_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_8_gaussian.npy
# Progress: 49/5000 videos processed
# Processing Speaker1_Session1_beach_9
# Saved: preprocessed_data\Speaker1_Session1_beach_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_beach_9_gaussian.npy
# Progress: 50/5000 videos processed
# Processing Speaker1_Session1_bird_1
# Saved: preprocessed_data\Speaker1_Session1_bird_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_1_gaussian.npy
# Progress: 51/5000 videos processed
# Processing Speaker1_Session1_bird_10
# Saved: preprocessed_data\Speaker1_Session1_bird_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_10_gaussian.npy
# Progress: 52/5000 videos processed
# Processing Speaker1_Session1_bird_2
# Saved: preprocessed_data\Speaker1_Session1_bird_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_2_gaussian.npy
# Progress: 53/5000 videos processed
# Processing Speaker1_Session1_bird_3
# Saved: preprocessed_data\Speaker1_Session1_bird_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_3_gaussian.npy
# Progress: 54/5000 videos processed
# Processing Speaker1_Session1_bird_4
# Saved: preprocessed_data\Speaker1_Session1_bird_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_4_gaussian.npy
# Progress: 55/5000 videos processed
# Processing Speaker1_Session1_bird_5
# Saved: preprocessed_data\Speaker1_Session1_bird_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_5_gaussian.npy
# Progress: 56/5000 videos processed
# Processing Speaker1_Session1_bird_6
# Saved: preprocessed_data\Speaker1_Session1_bird_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_bird_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_bird
no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_box_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_box_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_box_5_gaussian.npy
# Progress: 76/5000 videos processed
# Processing Speaker1_Session1_box_6
# Saved: preprocessed_data\Speaker1_Session1_box_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_box_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_box_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_box_6_gaussian.npy
# Progress: 77/5000 videos processed
# Processing Speaker1_Session1_box_7
# Saved: preprocessed_data\Speaker1_Session1_box_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_box_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_box_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_box_7_gaussian.npy
# Progress: 78/5000 videos processed
# Processing Speaker1_Session1_box_8
# Saved: preprocessed_data\Speaker1_Session1_box_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_box_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_box_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_box_8_gaussian.npy
# Progress: 79/5000 videos processed
# Processing Speaker1_Session1_box_9
# Saved: preprocessed_data\Speaker1_Session1_box_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_box_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_box_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_box_9_gaussian.npy
# Progress: 80/5000 videos processed
# Processing Speaker1_Session1_boy_1
# Saved: preprocessed_data\Speaker1_Session1_boy_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_1_gaussian.npy
# Progress: 81/5000 videos processed
# Processing Speaker1_Session1_boy_10
# Saved: preprocessed_data\Speaker1_Session1_boy_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_10_gaussian.npy
# Progress: 82/5000 videos processed
# Processing Speaker1_Session1_boy_2
# Saved: preprocessed_data\Speaker1_Session1_boy_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_2_gaussian.npy
# Progress: 83/5000 videos processed
# Processing Speaker1_Session1_boy_3
# Saved: preprocessed_data\Speaker1_Session1_boy_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_3_gaussian.npy
# Progress: 84/5000 videos processed
# Processing Speaker1_Session1_boy_4
# Saved: preprocessed_data\Speaker1_Session1_boy_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_4_gaussian.npy
# Progress: 85/5000 videos processed
# Processing Speaker1_Session1_boy_5
# Saved: preprocessed_data\Speaker1_Session1_boy_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_5_gaussian.npy
# Progress: 86/5000 videos processed
# Processing Speaker1_Session1_boy_6
# Saved: preprocessed_data\Speaker1_Session1_boy_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_6_gaussian.npy
# Progress: 87/5000 videos processed
# Processing Speaker1_Session1_boy_7
# Saved: preprocessed_data\Speaker1_Session1_boy_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_7_gaussian.npy
# Progress: 88/5000 videos processed
# Processing Speaker1_Session1_boy_8
# Saved: preprocessed_data\Speaker1_Session1_boy_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_8_gaussian.npy
# Progress: 89/5000 videos processed
# Processing Speaker1_Session1_boy_9
# Saved: preprocessed_data\Speaker1_Session1_boy_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_boy_9_gaussian.npy
# Progress: 90/5000 videos processed
# Processing Speaker1_Session1_car_1
# Saved: preprocessed_data\Speaker1_Session1_car_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_1_gaussian.npy
# Progress: 91/5000 videos processed
# Processing Speaker1_Session1_car_10
# Saved: preprocessed_data\Speaker1_Session1_car_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_10_gaussian.npy
# Progress: 92/5000 videos processed
# Processing Speaker1_Session1_car_2
# Saved: preprocessed_data\Speaker1_Session1_car_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_2_gaussian.npy
# Progress: 93/5000 videos processed
# Processing Speaker1_Session1_car_3
# Saved: preprocessed_data\Speaker1_Session1_car_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_3_gaussian.npy
# Progress: 94/5000 videos processed
# Processing Speaker1_Session1_car_4
# Saved: preprocessed_data\Speaker1_Session1_car_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_4_gaussian.npy
# Progress: 95/5000 videos processed
# Processing Speaker1_Session1_car_5
# Saved: preprocessed_data\Speaker1_Session1_car_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_5_gaussian.npy
# Progress: 96/5000 videos processed
# Processing Speaker1_Session1_car_6
# Saved: preprocessed_data\Speaker1_Session1_car_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_6_gaussian.npy
# Progress: 97/5000 videos processed
# Processing Speaker1_Session1_car_7
# Saved: preprocessed_data\Speaker1_Session1_car_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_7_gaussian.npy
# Progress: 98/5000 videos processed
# Processing Speaker1_Session1_car_8
# Saved: preprocessed_data\Speaker1_Session1_car_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_8_gaussian.npy
# Progress: 99/5000 videos processed
# Processing Speaker1_Session1_car_9
# Saved: preprocessed_data\Speaker1_Session1_car_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_car_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_car_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_car_9_gaussian.npy
# Progress: 100/5000 videos processed
# Processing Speaker1_Session1_cat_1
# Saved: preprocessed_data\Speaker1_Session1_cat_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_1_gaussian.npy
# Progress: 101/5000 videos processed
# Processing Speaker1_Session1_cat_10
# Saved: preprocessed_data\Speaker1_Session1_cat_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_10_gaussian.npy
# Progress: 102/5000 videos processed
# Processing Speaker1_Session1_cat_2
# Saved: preprocessed_data\Speaker1_Session1_cat_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_2_gaussian.npy
# Progress: 103/5000 videos processed
# Processing Speaker1_Session1_cat_3
# Saved: preprocessed_data\Speaker1_Session1_cat_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_3_gaussian.npy
# Progress: 104/5000 videos processed
# Processing Speaker1_Session1_cat_4
# Saved: preprocessed_data\Speaker1_Session1_cat_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_4_gaussian.npy
# Progress: 105/5000 videos processed
# Processing Speaker1_Session1_cat_5
# Saved: preprocessed_data\Speaker1_Session1_cat_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_5_gaussian.npy
# Progress: 106/5000 videos processed
# Processing Speaker1_Session1_cat_6
# Saved: preprocessed_data\Speaker1_Session1_cat_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_6_gaussian.npy
# Progress: 107/5000 videos processed
# Processing Speaker1_Session1_cat_7
# Saved: preprocessed_data\Speaker1_Session1_cat_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_7_gaussian.npy
# Progress: 108/5000 videos processed
# Processing Speaker1_Session1_cat_8
# Saved: preprocessed_data\Speaker1_Session1_cat_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_8_gaussian.npy
# Progress: 109/5000 videos processed
# Processing Speaker1_Session1_cat_9
# Saved: preprocessed_data\Speaker1_Session1_cat_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_cat_9_gaussian.npy
# Progress: 110/5000 videos processed
# Processing Speaker1_Session1_chair_1
# Saved: preprocessed_data\Speaker1_Session1_chair_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_1_gaussian.npy
# Progress: 111/5000 videos processed
# Processing Speaker1_Session1_chair_10
# Saved: preprocessed_data\Speaker1_Session1_chair_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_10_gaussian.npy
# Progress: 112/5000 videos processed
# Processing Speaker1_Session1_chair_2
# Saved: preprocessed_data\Speaker1_Session1_chair_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_2_gaussian.npy
# Progress: 113/5000 videos processed
# Processing Speaker1_Session1_chair_3
# Saved: preprocessed_data\Speaker1_Session1_chair_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_3_gaussian.npy
# Progress: 114/5000 videos processed
# Processing Speaker1_Session1_chair_4
# Saved: preprocessed_data\Speaker1_Session1_chair_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_4_gaussian.npy
# Progress: 115/5000 videos processed
# Processing Speaker1_Session1_chair_5
# Saved: preprocessed_data\Speaker1_Session1_chair_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_5_gaussian.npy
# Progress: 116/5000 videos processed
# Processing Speaker1_Session1_chair_6
# Saved: preprocessed_data\Speaker1_Session1_chair_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_6_gaussian.npy
# Progress: 117/5000 videos processed
# Processing Speaker1_Session1_chair_7
# Saved: preprocessed_data\Speaker1_Session1_chair_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_7_gaussian.npy
# Progress: 118/5000 videos processed
# Processing Speaker1_Session1_chair_8
# Saved: preprocessed_data\Speaker1_Session1_chair_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_8_gaussian.npy
# Progress: 119/5000 videos processed
# Processing Speaker1_Session1_chair_9
# Saved: preprocessed_data\Speaker1_Session1_chair_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_chair_9_gaussian.npy
# Progress: 120/5000 videos processed
# Processing Speaker1_Session1_clock_1
# Saved: preprocessed_data\Speaker1_Session1_clock_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_1_gaussian.npy
# Progress: 121/5000 videos processed
# Processing Speaker1_Session1_clock_10
# Saved: preprocessed_data\Speaker1_Session1_clock_10_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_10_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_10_gaussian.npy
# Progress: 122/5000 videos processed
# Processing Speaker1_Session1_clock_2
# Saved: preprocessed_data\Speaker1_Session1_clock_2_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_2_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_2_gaussian.npy
# Progress: 123/5000 videos processed
# Processing Speaker1_Session1_clock_3
# Saved: preprocessed_data\Speaker1_Session1_clock_3_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_3_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_3_gaussian.npy
# Progress: 124/5000 videos processed
# Processing Speaker1_Session1_clock_4
# Saved: preprocessed_data\Speaker1_Session1_clock_4_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_4_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_4_gaussian.npy
# Progress: 125/5000 videos processed
# Processing Speaker1_Session1_clock_5
# Saved: preprocessed_data\Speaker1_Session1_clock_5_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_5_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_5_gaussian.npy
# Progress: 126/5000 videos processed
# Processing Speaker1_Session1_clock_6
# Saved: preprocessed_data\Speaker1_Session1_clock_6_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_6_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_6_gaussian.npy
# Progress: 127/5000 videos processed
# Processing Speaker1_Session1_clock_7
# Saved: preprocessed_data\Speaker1_Session1_clock_7_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_7_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_7_gaussian.npy
# Progress: 128/5000 videos processed
# Processing Speaker1_Session1_clock_8
# Saved: preprocessed_data\Speaker1_Session1_clock_8_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_8_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_8_gaussian.npy
# Progress: 129/5000 videos processed
# Processing Speaker1_Session1_clock_9
# Saved: preprocessed_data\Speaker1_Session1_clock_9_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_9_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_clock_9_gaussian.npy
# Progress: 130/5000 videos processed
# Processing Speaker1_Session1_coat_1
# Saved: preprocessed_data\Speaker1_Session1_coat_1_no_aug.npy
# Saved: preprocessed_data\Speaker1_Session1_coat_1_brightness_negative.npy
# Saved: preprocessed_data\Speaker1_Session1_coat_1_contrast.npy
# Saved: preprocessed_data\Speaker1_Session1_coat
no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_10_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_10_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_10_gaussian.npy
# Progress: 4992/5000 videos processed
# Processing Speaker4_Session5_yes_2
# Saved: preprocessed_data\Speaker4_Session5_yes_2_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_2_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_2_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_2_gaussian.npy
# Progress: 4993/5000 videos processed
# Processing Speaker4_Session5_yes_3
# Saved: preprocessed_data\Speaker4_Session5_yes_3_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_3_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_3_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_3_gaussian.npy
# Progress: 4994/5000 videos processed
# Processing Speaker4_Session5_yes_4
# Saved: preprocessed_data\Speaker4_Session5_yes_4_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_4_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_4_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_4_gaussian.npy
# Progress: 4995/5000 videos processed
# Processing Speaker4_Session5_yes_5
# Saved: preprocessed_data\Speaker4_Session5_yes_5_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_5_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_5_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_5_gaussian.npy
# Progress: 4996/5000 videos processed
# Processing Speaker4_Session5_yes_6
# Saved: preprocessed_data\Speaker4_Session5_yes_6_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_6_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_6_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_6_gaussian.npy
# Progress: 4997/5000 videos processed
# Processing Speaker4_Session5_yes_7
# Saved: preprocessed_data\Speaker4_Session5_yes_7_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_7_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_7_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_7_gaussian.npy
# Progress: 4998/5000 videos processed
# Processing Speaker4_Session5_yes_8
# Saved: preprocessed_data\Speaker4_Session5_yes_8_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_8_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_8_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_8_gaussian.npy
# Progress: 4999/5000 videos processed
# Processing Speaker4_Session5_yes_9
# Saved: preprocessed_data\Speaker4_Session5_yes_9_no_aug.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_9_brightness_negative.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_9_contrast.npy
# Saved: preprocessed_data\Speaker4_Session5_yes_9_gaussian.npy
# Progress: 5000/5000 videos processed

# %%
import cv2
import numpy as np
import os
import dlib
import cupy as cp
import tensorflow as tf

# Enable GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# Initialize face detector and predictor
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('external_models/shape_predictor_68_face_landmarks.dat')

# GPU-accelerated augmentation functions
def augment_brightness(frame_gpu, factor=1.1):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_strong(frame_gpu, factor=1.3):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_brightness_negative(frame_gpu, factor=0.7):
    return cp.clip(frame_gpu * factor, 0, 1)  # Clip to 0-1 range

def augment_contrast(frame_gpu, factor=1.1):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_strong(frame_gpu, factor=1.3):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_contrast_negative(frame_gpu, factor=0.7):
    mean_intensity = cp.mean(frame_gpu)
    return cp.clip((1 - factor) * mean_intensity + factor * frame_gpu, 0, 1)  # Clip to 0-1 range

def augment_rotation(frame_gpu, angle=10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_strong(frame_gpu, angle=20):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_rotation_negative(frame_gpu, angle=-10):
    k = int(abs(angle) / 90)
    return cp.rot90(frame_gpu, k=k) if angle >= 0 else cp.rot90(frame_gpu, k=-k)

def augment_flip(frame_gpu):
    return cp.fliplr(frame_gpu)

def augment_gaussian_noise(frame_gpu, mean=0, stddev=0.005):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_strong(frame_gpu, mean=0, stddev=0.01):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def augment_gaussian_noise_negative(frame_gpu, mean=0, stddev=0.003):
    noise = cp.random.normal(mean, stddev, frame_gpu.shape).astype(cp.float32)
    return cp.clip(frame_gpu + noise, 0, 1)  # Clip to 0-1 range

def preprocess_frame(frame):
    # Convert to grayscale
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Detect face
    faces = detector(gray_frame)
    
    if len(faces) > 0:
        face = faces[0]
        landmarks = predictor(gray_frame, face)
        landmarks = np.array([[p.x, p.y] for p in landmarks.parts()])[48:68]  # Lip region
        x, y, w, h = cv2.boundingRect(landmarks)
        roi = gray_frame[y:y+h, x:x+w]
    else:
        roi = gray_frame
    
    # Resize to 128x128
    resized_frame = cv2.resize(roi, (256, 256))
    
    # Move to GPU and normalize
    frame_gpu = cp.asarray(resized_frame, dtype=cp.float32)
    frame_gpu = frame_gpu / 255.0  # Normalize to 0-1 range
    
    return frame_gpu

def adjust_video_length(frames_list, target_length=60):
    # Convert list of CuPy arrays to a single stacked array
    frames = cp.stack(frames_list)
    length = len(frames)
    
    if length > target_length:
        return cp.asnumpy(frames[:target_length])
    
    # Move to CPU for padding operation
    frames_cpu = cp.asnumpy(frames)
    pad_width = target_length - length
    left_pad = pad_width // 2
    right_pad = pad_width - left_pad
    
    padded = np.pad(frames_cpu, ((left_pad, right_pad), (0, 0), (0, 0)), mode='reflect')
    return padded[:target_length]

def process_video(video_path, output_folder, video_name):
    print(f"Processing {video_name}")
    
    # Read video frames
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frames.append(frame)
    cap.release()
    
    # Define augmentation combinations
    augmentation_combinations = [
        ('no_aug', []),
        # ('brightness', [augment_brightness]),
        # ('brightness_strong', [augment_brightness_strong]),
        ('brightness_negative', [augment_brightness_negative]),
        ('contrast', [augment_contrast]),
        # ('contrast_strong', [augment_contrast_strong]), 
        # ('contrast_negative', [augment_contrast_negative]),
        # ('rotation', [augment_rotation]),
        # ('rotation_strong', [augment_rotation_strong]),
        # ('rotation_negative', [augment_rotation_negative]),
        # ('flip', [augment_flip]),
        ('gaussian', [augment_gaussian_noise]),
        # ('gaussian_strong', [augment_gaussian_noise_strong]),
        # ('gaussian_negative', [augment_gaussian_noise_negative])
    ]
    
    # Process frames
    processed_frames = [preprocess_frame(frame) for frame in frames]
    
    for aug_level, aug_list in augmentation_combinations:
        augmented_frames = []
        
        for frame_gpu in processed_frames:
            current_frame = cp.copy(frame_gpu)
            
            # Apply augmentations
            for aug_func in aug_list:
                current_frame = aug_func(current_frame)
            
            augmented_frames.append(current_frame)
        
        # Adjust to 60 frames and save
        adjusted_frames = adjust_video_length(augmented_frames)
        output_path = os.path.join(output_folder, f"{video_name}_{aug_level}.npy")
        np.save(output_path, adjusted_frames.astype(np.float16))
        print(f"Saved: {output_path}")
        
        # Free GPU memory
        cp.get_default_memory_pool().free_all_blocks()

def preprocess_videos(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_videos = sum([len(files) for _, _, files in os.walk(input_folder)])
    processed = 0
    
    for session_folder in os.listdir(input_folder):
        session_path = os.path.join(input_folder, session_folder)
        if os.path.isdir(session_path):
            for video_file in os.listdir(session_path):
                video_path = os.path.join(session_path, video_file)
                video_name = os.path.splitext(video_file)[0]
                
                try:
                    process_video(video_path, output_folder, video_name)
                    processed += 1
                    print(f"Progress: {processed}/{total_videos} videos processed")
                except Exception as e:
                    print(f"Error processing {video_name}: {e}")
                    
                # Free GPU memory after each video
                cp.get_default_memory_pool().free_all_blocks()

if __name__ == "__main__":
    input_folder = 'test_data'
    output_folder = 'preprocessed_test_data'
    
    # Clear any existing GPU memory
    cp.get_default_memory_pool().free_all_blocks()
    
    preprocess_videos(input_folder, output_folder)
# Out:
# Processing TestSpeaker1_Session1_apple_1
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_1_gaussian.npy
# Progress: 1/750 videos processed
# Processing TestSpeaker1_Session1_apple_10
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_10_gaussian.npy
# Progress: 2/750 videos processed
# Processing TestSpeaker1_Session1_apple_11
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_11_gaussian.npy
# Progress: 3/750 videos processed
# Processing TestSpeaker1_Session1_apple_12
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_12_gaussian.npy
# Progress: 4/750 videos processed
# Processing TestSpeaker1_Session1_apple_13
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_13_gaussian.npy
# Progress: 5/750 videos processed
# Processing TestSpeaker1_Session1_apple_14
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_14_gaussian.npy
# Progress: 6/750 videos processed
# Processing TestSpeaker1_Session1_apple_15
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_15_gaussian.npy
# Progress: 7/750 videos processed
# Processing TestSpeaker1_Session1_apple_16
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_16_gaussian.npy
# Progress: 8/750 videos processed
# Processing TestSpeaker1_Session1_apple_17
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_17_gaussian.npy
# Progress: 9/750 videos processed
# Processing TestSpeaker1_Session1_apple_18
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_18_gaussian.npy
# Progress: 10/750 videos processed
# Processing TestSpeaker1_Session1_apple_19
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_19_gaussian.npy
# Progress: 11/750 videos processed
# Processing TestSpeaker1_Session1_apple_2
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_2_gaussian.npy
# Progress: 12/750 videos processed
# Processing TestSpeaker1_Session1_apple_20
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_20_gaussian.npy
# Progress: 13/750 videos processed
# Processing TestSpeaker1_Session1_apple_21
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_21_gaussian.npy
# Progress: 14/750 videos processed
# Processing TestSpeaker1_Session1_apple_22
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_22_gaussian.npy
# Progress: 15/750 videos processed
# Processing TestSpeaker1_Session1_apple_23
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_23_gaussian.npy
# Progress: 16/750 videos processed
# Processing TestSpeaker1_Session1_apple_24
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_no_aug.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_brightness_negative.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple_24_contrast.npy
# Saved: preprocessed_test_data\TestSpeaker1_Session1_apple